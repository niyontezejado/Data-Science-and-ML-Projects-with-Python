# %%
# Import libraries

import pandas as pd
import matplotlib.pyplot as plt

# import fbprophet
# from fbprophet.plot import add_changepoints_to_plot
import warnings

# %%
# pip install matplotlib

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Projects/1 Daily Birth/daily-total-female-births-CA.csv',parse_dates=['date'], date_parser=pd.to_datetime)
data
# Out:
#           date  births
# 0   1959-01-01      35
# 1   1959-01-02      32
# 2   1959-01-03      30
# 3   1959-01-04      31
# 4   1959-01-05      44
# ..         ...     ...
# 360 1959-12-27      37
# 361 1959-12-28      52
# 362 1959-12-29      48
# 363 1959-12-30      55
# 364 1959-12-31      50
#
# [365 rows x 2 columns]

# %%
# Check the dataset information
data.info()
print("*"*24)
data.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    datetime64[ns]
#  1   births  365 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB
# ************************
#       date  births
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False
# ..     ...     ...
# 360  False   False
# 361  False   False
# 362  False   False
# 363  False   False
# 364  False   False
#
# [365 rows x 2 columns]

# %%
data.loc[12]
# Out:
# date      1959-01-13 00:00:00
# births                     55
# Name: 12, dtype: object

# %%
# Plot
import matplotlib.dates as mdates

date_column = data['date']
births_column = data['births']

plt.figure(figsize=(12, 4))
plt.plot(date_column,births_column, color = 'm')

plt.title("Daily total female births")
plt.xlabel("Date")
plt.ylabel("Number of birth")
plt.show()

# %%
"""create a Prophet instance to apply the seasonality effects for the task of daily births forecast with Machine Learning"""

from statsmodels.tsa.statespace.tools import diff

fig = plt.figure(figsize=(12,4))
plt.plot(diff(births_column),color='g');
plt.xlabel('Date')
plt.ylabel('Number of Births')
plt.title('Differenced series')
plt.show()
